# %%
import os, sys
from pyspark import SparkContext, SparkConf
appName = "miApp"
master="local[*]"

conf = SparkConf().setAppName(appName).setMaster(master)
sc = SparkContext(conf=conf)

# %%
#print(os.getcwd())
textFile = sc.textFile("../../datasets/worldbank-millennium-development-goals.csv")

# datasets at:
#https://datasource.kapsarc.org/explore/dataset/worldbank-millennium-development-goals/export/
#https://datasource.kapsarc.org/explore/dataset/worldbank-health-nutrition-and-population-statistics/export/

# %%
print(textFile.count()) # Number of items in this RDD

textFile.first()  # First item in this RDD
# Out:
# 98939
# 'Country Name;Country Code;Indicator Name;Indicator Code;Year;Value'

# %%
textFile.filter(lambda line: "Spain" in line).count()  # How many lines contain "Spain"?
# Out:
# 144

# %%
# find the line with the most words (lambda format)
textFile.map(lambda line: len(line.split())).reduce(lambda a, b: a if (a > b) else b)
# Out:
# 26

# %%
# find the line with the most words (function format)
def max(a, b):
     if a > b:
         return a
     else:
         return b


textFile.map(lambda line: len(line.split())).reduce(max)
# Out:
# 26

# %%
# One common data flow pattern is MapReduce, as popularized by Hadoop. Spark can implement MapReduce flows easily:
wordCounts = textFile.flatMap(lambda line: line.split()).map(lambda word: (word, 1)).reduceByKey(lambda a, b: a+b)

# %%
wordCounts.collect()
# Out:
# [('Country', 1),
#  ('Code;Indicator', 1),
#  ('Code;Year;Value', 1),
#  ('cases', 761),
#  ('reported;SH.STA.MALR;1998;', 12),
#  ('reported;SH.STA.MALR;2000;', 25),
#  ('Grenada;GRD;Marine', 6),
#  ('protected', 1432),
#  ('areas', 1432),
#  ('of', 62431),
#  ('waters);ER.MRN.PTMR.ZS;1993;', 8),
#  ('waters);ER.MRN.PTMR.ZS;1995;', 13),
#  ('waters);ER.MRN.PTMR.ZS;2003;0.022562666963014', 1),
#  ('ratio', 4522),
#  ('estimate,', 766),
#  ('live', 2259),
#  ('births);SH.STA.MMRT;2013;27.0', 1),
#  ('births);SH.STA.MMRT;1992;38.0', 1),
#  ('Grenada;GRD;Mortality', 7),
#  ('rate,', 6656),
#  ('(per', 5200),
#  ('Grenada;GRD;Net', 39),
#  ('developed', 9691),
#  ('countries', 13184),
#  ('US$);DC.ODA.TLDC.CD;1994;', 25),
#  ('US$);DC.ODA.TLDC.CD;2001;', 23),
#  ('GNI);DC.ODA.TOTL.GN.ZS;2009;', 27),
#  ('(constant', 3005),
#  ('2012', 779),
#  ('US$);DC.ODA.TOTL.KD;2010;', 23),
#  ('US$);DC.ODA.TOTL.KD;1990;', 30),
#  ('US$);DC.ODA.TOTL.KD;1998;', 28),
#  ('GNI);DT.ODA.ODAT.GN.ZS;2011;1.63713435795736', 1),
#  ('GNI);DT.ODA.ODAT.GN.ZS;2001;2.29436453913213', 1),
#  ('US$);DT.ODA.ODAT.PC.ZS;2014;', 23),
#  ('US$);DT.ODA.ODAT.PC.ZS;2006;258.95797017238', 1),
#  ('official', 2183),
#  ('development', 1477),
#  ('assistance', 1477),
#  ('US$);DT.ODA.ODAT.CD;2009;47810000.0', 1),
#  ('Grenada;GRD;Percentage', 5),
#  ('females', 3665),
#  ('15-49', 1487),
#  ('comprehensive', 1487),
#  ('correct', 2967),
#  ('knowledge', 2967),
#  ('HIV', 1487),
#  ('prevent', 2967),
#  ('misconceptions)', 1487),
#  ('(%);SH.HIV.KNOW.FE.ZS;1998;', 26),
#  ('males', 3746),
#  ('(%);SH.HIV.KNOW.MA.ZS;2006;', 29),
#  ('last', 3698),
#  ('grade', 2164),
#  ('female', 8870),
#  ('cohort);SE.PRM.PRSL.FE.ZS;2013;', 32),
#  ('cohort);SE.PRM.PRSL.FE.ZS;1997;', 19),
#  ('cohort);SE.PRM.PRSL.FE.ZS;2006;', 10),
#  ('cohort);SE.PRM.PRSL.MA.ZS;1994;', 11),
#  ('cohort);SE.PRM.PRSL.ZS;1997;', 12),
#  ('cohort);SE.PRM.PRSL.ZS;2008;', 11),
#  ('total;SP.POP.TOTL;1994;99403.0', 1),
#  ('total;SP.POP.TOTL;2000;101620.0', 1),
#  ('total;SP.POP.TOTL;2005;102951.0', 1),
#  ('gap', 3656),
#  ('at', 10455),
#  ('(2011', 2952),
#  ('PPP)', 2952),
#  ('(%);SI.POV.GAP2;2014;', 27),
#  ('(%);SI.POV.GAP2;1993;', 18),
#  ('$1.90', 1496),
#  ('population);SI.POV.DDAY;2003;', 25),
#  ('population);SI.POV.2DAY;1996;', 25),
#  ('population);SI.POV.2DAY;1998;', 30),
#  ('factor,', 1482),
#  ('$);PA.NUS.PPP;;', 36),
#  ('private', 743),
#  ('consumption', 743),
#  ('$);PA.NUS.PRVT.PP;2009;2.05789260551166', 1),
#  ('women', 5191),
#  ('(%);SH.STA.ANVC.ZS;2014;', 34),
#  ('(%);SH.STA.ANVC.ZS;2012;', 36),
#  ('15-24);SH.HIV.1524.FE.ZS;1993;', 14),
#  ('15-24);SH.HIV.1524.MA.ZS;1999;', 11),
#  ('population', 8066),
#  ('15-49);SH.DYN.AIDS.ZS;1999;', 10),
#  ('undernourishment', 735),
#  ('population);SN.ITK.DEFC.ZS;1990;', 27),
#  ('underweight,', 744),
#  ('Grenada;GRD;Primary', 5),
#  ('completion', 746),
#  ('relevant', 746),
#  ('group);SE.PRM.CMPT.ZS;2011;', 12),
#  ('group);SE.PRM.CMPT.ZS;2003;100.281578063965', 1),
#  ('seats', 741),
#  ('in', 5864),
#  ('Guam;GUM;Population,', 6),
#  ('Guam;GUM;Poverty', 34),
#  ('(%);SI.POV.GAPS;2005;', 29),
#  ('(%);SI.POV.GAP2;2008;', 18),
#  ('(%);SI.POV.NAGP;2009;', 25),
#  ('Arab', 2267),
#  ('15+,', 2156),
#  ('estimate);SL.EMP.TOTL.SP.ZS;2014;', 26),
#  ('estimate);SL.EMP.1524.SP.FE.ZS;2010;10.4645331798002', 1),
#  ('estimate);SL.EMP.1524.SP.MA.ZS;2001;37.1717751421733', 1),
#  ('estimate);SL.EMP.1524.SP.MA.ZS;2005;39.3287765344067', 1),
#  ('estimate);SL.EMP.1524.SP.ZS;2011;23.640689182021', 1),
#  ('World;ARB;Energy', 8),
#  ('use', 3019),
#  ('equivalent)', 727),
#  ('$1,000', 727),
#  ('2011', 1485),
#  ('PPP);EG.USE.COMM.GD.PP.KD;2002;117.129932596367', 1),
#  ('PPP);EG.USE.COMM.GD.PP.KD;2007;108.887367605978', 1),
#  ('World;ARB;Fertility', 6),
#  ('woman);SP.DYN.TFRT.IN;1991;4.95731828263643', 1),
#  ('woman);SP.DYN.TFRT.IN;2008;3.35929919340794', 1),
#  ('telephone', 697),
#  ('subscriptions', 1475),
#  ('100', 2223),
#  ('World;ARB;Forest', 17),
#  ('area', 1456),
#  ('World;ARB;GDP', 15),
#  ('person', 741),
#  ('1990', 741),
#  ('PPP', 2274),
#  ('$);SL.GDP.PCAP.EM.KD;1990;', 13),
#  ('$', 1533),
#  ('equivalent);EG.GDP.PUSE.KO.PP.KD;1994;8.37773874748697', 1),
#  ('World;ARB;GNI', 10),
#  ('capita,', 762),
#  ('US$);NY.GNP.PCAP.CD;1993;2101.0059153003', 1),
#  ('US$);NY.GNP.ATLS.CD;2001;704219887676.807', 1),
#  ('(excluding', 1474),
#  ('arms)', 1474),
#  ('admitted', 1474),
#  ('free', 1474),
#  ('tariffs', 5887),
#  ('developing', 2978),
#  ('arms);TM.MRC.NOTX.LD.ZS;;', 33),
#  ('arms);TM.MRC.NOTX.LD.ZS;2009;', 24),
#  ('formation', 724),
#  ('World;ARB;Immunization,', 10),
#  ('measles', 676),
#  ('12-23', 676),
#  ('months);SH.IMM.MEAS;1994;75.11935733932', 1),
#  ('sanitation', 720),
#  ('access);SH.STA.ACSN;2010;78.2990055056806', 1),
#  ('access);SH.STA.ACSN;2008;77.4357516129517', 1),
#  ('water', 739),
#  ('source', 739),
#  ('access);SH.H2O.SAFE.ZS;1994;82.0964539800099', 1),
#  ('access);SH.H2O.SAFE.ZS;1999;82.4793679506593', 1),
#  ('World;ARB;Income', 14),
#  ('share', 731),
#  ('20%;SI.DST.FRST.20;1991;', 28),
#  ('20%;SI.DST.FRST.20;1993;', 30),
#  ('World;ARB;Literacy', 29),
#  ('above);SE.ADT.LITR.ZS;1999;', 26),
#  ('above);SE.ADT.LITR.ZS;1998;', 23),
#  ('15-24);SE.ADT.1524.LT.MA.ZS;2009;', 27),
#  ('15-24);SE.ADT.1524.LT.ZS;2011;', 20),
#  ('15-24);SE.ADT.1524.LT.ZS;1992;', 26),
#  ('waters);ER.MRN.PTMR.ZS;2007;4.18675977691824', 1),
#  ('World;ARB;Maternal', 9),
#  ('births);SH.STA.MMRT;2010;174.0', 1),
#  ('births);SH.STA.MMRT;2002;226.0', 1),
#  ('World;ARB;Mobile', 9),
#  ('cellular', 778),
#  ('under-5', 1475),
#  ('births);SH.DYN.MORT;1993;73.2855564659743', 1),
#  ('births);SH.DYN.MORT;2003;55.0878217295702', 1),
#  ('World;ARB;Net', 68),
#  ('GNI);DC.ODA.TLDC.GN.ZS;2012;', 32),
#  ('US$);DC.ODA.TLDC.CD;2004;', 20),
#  ('GNI);DC.ODA.TOTL.GN.ZS;;', 31),
#  ('GNI);DC.ODA.TOTL.GN.ZS;1993;', 34),
#  ('GNI);DC.ODA.TOTL.GN.ZS;2005;', 23),
#  ('US$);DC.ODA.TOTL.KD;2003;', 24),
#  ('US$);DC.ODA.TOTL.CD;;', 25),
#  ('US$);DT.ODA.ODAT.CD;2000;5039440000.0', 1),
#  ('(%);SH.HIV.KNOW.MA.ZS;2001;', 30),
#  ('cohort);SE.PRM.PRSL.FE.ZS;1997;76.8861083984375', 1),
#  ('cohort);SE.PRM.PRSL.MA.ZS;1992;75.3780288696289', 1),
#  ('cohort);SE.PRM.PRSL.ZS;1991;72.1818618774414', 1),
#  ('cohort);SE.PRM.PRSL.ZS;2008;81.9701614379883', 1),
#  ('World;ARB;Population', 8),
#  ('living', 1421),
#  ('slums', 718),
#  ('population);EN.POP.SLUM.UR.ZS;2004;', 37),
#  ('total;SP.POP.TOTL;2014;', 30),
#  ('total;SP.POP.TOTL;2003;299853418.0', 1),
#  ('total;SP.POP.TOTL;2001;287358599.0', 1),
#  ('World;ARB;Poverty', 56),
#  ('(%);SI.POV.GAPS;1997;', 25),
#  ('(%);SI.POV.NAGP;1991;', 23),
#  ('(%);SI.POV.NAGP;1995;', 34),
#  ('(%);SI.POV.NAGP;1999;', 26),
#  ('(%);SI.POV.NAGP;2003;', 33),
#  ('Colombia;COL;Forest', 12),
#  ('(sq.', 729),
#  ('Colombia;COL;GDP', 19),
#  ('equivalent);EG.GDP.PUSE.KO.PP.KD;2008;15.9900990155563', 1),
#  ('equivalent);EG.GDP.PUSE.KO.PP.KD;2009;15.6793912045714', 1),
#  ('US$);NY.GNP.PCAP.CD;2004;2580.0', 1),
#  ('Colombia;COL;GNI,', 6),
#  ('Colombia;COL;Goods', 13),
#  ('Colombia;COL;Immunization,', 5),
#  ('months);SH.IMM.MEAS;2001;93.0', 1),
#  ('months);SH.IMM.MEAS;2008;95.0', 1),
#  ('Colombia;COL;Improved', 12),
#  ('access);SH.STA.ACSN;1998;73.6', 1),
#  ('access);SH.H2O.SAFE.ZS;1997;89.5', 1),
#  ('access);SH.H2O.SAFE.ZS;2004;90.3', 1),
#  ('Colombia;COL;Incidence', 4),
#  ('tuberculosis', 718),
#  ('people);SH.TBS.INCD;1993;50.0', 1),
#  ('people);SH.TBS.INCD;1996;47.0', 1),
#  ('expectancy', 748),
#  ('(years);SP.DYN.LE00.IN;2005;72.2606097560976', 1),
#  ('(years);SP.DYN.LE00.IN;2009;73.1580731707317', 1),
#  ('Colombia;COL;Literacy', 23),
#  ('15-24);SE.ADT.1524.LT.ZS;2012;', 30),
#  ('reported;SH.STA.MALR;1999;66845.0', 1),
#  ('Colombia;COL;Marine', 7),
#  ('waters);ER.MRN.PTMR.ZS;1991;0.942721613058235', 1),
#  ('waters);ER.MRN.PTMR.ZS;1992;0.942721613058235', 1),
#  ('waters);ER.MRN.PTMR.ZS;2003;5.17076694737147', 1),
#  ('Colombia;COL;Mobile', 9),
#  ('people);IT.CEL.SETS.P2;2001;8.05071460961914', 1),
#  ('births);SH.DYN.MORT;1996;28.9', 1),
#  ('Colombia;COL;Net', 50),
#  ('GNI);DC.ODA.TLDC.GN.ZS;1995;', 33),
#  ('US$);DC.ODA.TOTL.CD;2002;', 26),
#  ('GNI);DT.ODA.ODAT.GN.ZS;2013;0.232867719548992', 1),
#  ('US$);DT.ODA.ODAT.PC.ZS;2008;21.527012679125', 1),
#  ('US$);DT.ODA.ALLD.CD;1992;231640000.0', 1),
#  ('Colombia;COL;Percentage', 14),
#  ('Colombia;COL;Total', 16),
#  ('service', 1433),
#  ('exports', 1433),
#  ('primary', 5117),
#  ('income);DT.TDS.DECT.EX.ZS;2007;23.042040628028', 1),
#  ('Colombia;COL;Trade', 6),
#  ('GDP);NE.TRD.GNFS.ZS;2014;37.5309461589733', 1),
#  ('Colombia;COL;Tuberculosis', 23),
#  ('rate', 2937),
#  ('people);SH.TBS.MORT;2007;2.5', 1),
#  ('success', 716),
#  ('new', 716),
#  ('cases);SH.TBS.CURE.ZS;2004;80.0', 1),
#  ('married', 686),
#  ('15-49);SP.UWT.TFRT;1992;', 32),
#  ('(%);SI.POV.URGP;1991;', 21),
#  ('(%);SI.POV.URGP;2004;', 30),
#  ('population);SI.POV.URHC;2007;', 27),
#  ('Colombia;COL;Use', 11),
#  ('insecticide-treated', 711),
#  ('population);SH.MLR.NETS.ZS;2011;', 29),
#  ('Colombia;COL;Vulnerable', 18),
#  ('employment,', 2242),
#  ('employment);SL.EMP.VULN.FE.ZS;1998;30.2999992370605', 1),
#  ('enrollment', 777),
#  ('school', 2253),
#  ('children);SE.PRM.TENR;2014;', 34),
#  ('children);SE.PRM.TENR;2013;83.4171524047852', 1),
#  ('children);SE.PRM.TENR;2003;', 10),
#  ('children);SE.PRM.TENR;2001;', 7),
#  ('Comoros;COM;Adolescent', 6),
#  ('fertility', 759),
#  ('15-19);SP.ADO.TFRT;1992;108.201', 1),
#  ('15-19);SP.ADO.TFRT;1995;102.645', 1),
#  ('support', 733),
#  ('estimate', 733),
#  ('Comoros;COM;AIDS', 6),
#  ('estimated', 741),
#  ('(UNAIDS', 741),
#  ('freshwater', 1520),
#  ('withdrawals,', 758),
#  ('internal', 1520),
#  ('therapy', 703),
#  ('coverage', 703),
#  ('HIV);SH.HIV.ARTC.ZS;1992;', 28),
#  ('(%);TM.TAX.AGRI.CD.DV;2005;', 19),
#  ('(%);TM.TAX.AGRI.CD.LD;2006;', 27),
#  ('(%);TM.TAX.CLTH.CD.DV;1991;', 27),
#  ('(%);TM.TAX.CLTH.CD.LD;2012;', 28),
#  ('(%);TM.TAX.CLTH.CD.LD;1994;', 26),
#  ('(%);TM.TAX.CLTH.CD.LD;2001;', 29),
#  ('middle', 2879),
#  ('income;LMC;Tuberculosis', 24),
#  ('cases);SH.TBS.CURE.ZS;2003;80.0', 3),
#  ('15-49);SP.UWT.TFRT;2004;', 29),
#  ('15-49);SP.UWT.TFRT;2008;', 34),
#  ('income;LMC;Urban', 14),
#  ('population);SI.POV.URHC;1991;', 30),
#  ('income;LMC;Use', 8),
#  ('population);SH.MLR.NETS.ZS;2006;', 25),
#  ('employment);SL.EMP.VULN.ZS;1995;', 20),
#  ('Middle', 3071),
#  ('East', 4940),
#  ('North', 3112),
#  ('(all', 5634),
#  ('income', 5634),
#  ('children);SE.PRM.TENR;2004;91.3850173950195', 1),
#  ('levels);MEA;Adolescent', 10),
#  ('15-19);SP.ADO.TFRT;2007;37.973650768155', 1),
#  ('levels);MEA;Agricultural', 7),
#  ('HIV);SH.HIV.ARTC.ZS;2004;2.47815820543093', 1),
#  ('levels);MEA;ARI', 13),
#  ('provider);SH.STA.ARIC.ZS;1998;', 34),
#  ('levels);MEA;Average', 55),
#  ('(%);TM.TAX.AGRI.CD.DV;2013;', 29),
#  ('(%);TM.TAX.AGRI.CD.LD;2013;', 21),
#  ('(%);TM.TAX.CLTH.CD.DV;2010;', 23),
#  ('(%);TM.TAX.CLTH.CD.DV;2002;', 26),
#  ('(%);TM.TAX.CLTH.CD.LD;1998;', 28),
#  ('textile', 1443),
#  ('(%);TM.TAX.TXTL.CD.LD;2011;', 19),
#  ('(%);TM.TAX.TXTL.CD.LD;1992;', 26),
#  ('levels);MEA;Bilateral', 24),
#  ('commitments', 3026),
#  ('is', 1530),
#  ('untied', 1530),
#  ('US$);DC.ODA.UNTD.CD;1995;', 33),
#  ('sector-allocable', 1458),
#  ('basic', 1458),
#  ('social', 1458),
#  ('bilateral', 2950),
#  ('US$);DC.ODA.SOCL.CD;2004;', 22),
#  ('levels);MEA;Births', 11),
#  ('staff', 783),
#  ('total);SH.STA.BRTC.ZS;2012;', 32),
#  ('total);SH.STA.BRTC.ZS;1997;', 26),
#  ('levels);MEA;Children', 12),
#  ('HIV/AIDS;SH.HIV.ORPH;2008;', 27),
#  ('fever', 726),
#  ('fever);SH.MLR.TRET.ZS;1992;', 28),
#  ('levels);MEA;CO2', 30),
#  ('emissions', 2250),
#  ('GDP);EN.ATM.CO2E.PP.GD;1990;0.525183916216613', 1),
#  ('(metric', 694),
#  ('capita);EN.ATM.CO2E.PC;2014;', 37),
#  ('capita);EN.ATM.CO2E.PC;;', 27),
#  ('capita);EN.ATM.CO2E.PC;1993;4.29778611775652', 1),
#  ('capita);EN.ATM.CO2E.PC;2000;4.67595090193969', 1),
#  ('capita);EN.ATM.CO2E.PC;2009;5.78767704610511', 1),
#  ('HIV/AIDS,', 1480),
#  ('misconceptions);SH.HIV.1524.KW.FE.ZS;1992;', 29),
#  ('misconceptions);SH.HIV.1524.KW.MA.ZS;1991;', 30),
#  ('15-49);SH.CON.AIDS.FE.ZS;1990;', 32),
#  ('15-49);SH.CON.AIDS.FE.ZS;2009;', 25),
#  ('use,', 1502),
#  ('15-24);SH.CON.1524.FE.ZS;2003;', 28),
#  ('15-24);SH.CON.1524.MA.ZS;2012;', 30),
#  ('levels);MEA;Contributing', 28),
#  ('family', 2220),
#  ('workers,', 2220),
#  ('employed);SL.FAM.WORK.FE.ZS;2014;', 28),
#  ('employed);SL.FAM.WORK.MA.ZS;2011;', 18),
#  ('employed);SL.FAM.WORK.MA.ZS;1992;', 13),
#  ('employed);SL.FAM.WORK.ZS;1994;', 20),
#  ('employed);SL.FAM.WORK.ZS;1999;', 13),
#  ('employed);SL.FAM.WORK.ZS;2008;', 21),
#  ('MDRI', 1419),
#  ('cumulative', 2184),
#  ('US$', 2184),
#  ('end-2009', 2184),
#  ('NPV', 2184),
#  ('terms;DT.HPC.TOTL.PV;2014;', 23),
#  ('terms;DT.HPC.COMR.PV;2004;', 32),
#  ('full', 739),
#  ('terms;DT.HPC.MDRI.PV;1991;', 30),
#  ('(PPG', 724),
#  ('IMF', 724),
#  ('only,', 724),
#  ('income);DT.TDS.DPPF.XP.ZS;2013;', 6),
#  ('(%);SI.POV.GAPS;1996;', 30),
#  ('(%);SI.POV.GAP2;2012;', 17),
#  ('(%);SI.POV.GAP2;1990;', 22),
#  ('(%);SI.POV.GAP2;2005;', 23),
#  ('population);SI.POV.DDAY;2013;', 27),
#  ('population);SI.POV.2DAY;2013;', 24),
#  ('population);SI.POV.NAHC;2012;', 23),
#  ('population);SI.POV.NAHC;1993;', 28),
#  ('population);SI.POV.NAHC;2007;', 32),
#  ('$);PA.NUS.PPP;1990;1.86866405101265', 1),
#  ('$);PA.NUS.PRVT.PP;2005;1.91857242809483', 1),
#  ('Barbados;BRB;Pregnant', 8),
#  ('(%);SH.STA.ANVC.ZS;;', 28),
#  ('four', 761),
#  ('Barbados;BRB;Prevalence', 26),
#  ('15-24);SH.HIV.1524.FE.ZS;2012;', 15),
#  ('15-24);SH.HIV.1524.FE.ZS;2006;', 16),
#  ('15-24);SH.HIV.1524.MA.ZS;2013;', 16),
#  ('15-24);SH.HIV.1524.MA.ZS;1997;', 14),
#  ('15-49);SH.DYN.AIDS.ZS;2006;', 14),
#  ('population);SN.ITK.DEFC.ZS;2011;5.0', 4),
#  ('population);SN.ITK.DEFC.ZS;1995;5.0', 4),
#  ('population);SN.ITK.DEFC.ZS;2000;5.0', 1),
#  ('population);SN.ITK.DEFC.ZS;2006;6.7', 1),
#  ('5);SH.STA.MALN.ZS;1993;', 28),
#  ('5);SH.STA.MALN.ZS;2001;', 20),
#  ('Barbados;BRB;Primary', 9),
#  ('group);SE.PRM.CMPT.ZS;1992;', 10),
#  ('group);SE.PRM.CMPT.ZS;1998;', 13),
#  ('group);SE.PRM.CMPT.ZS;2003;106.373519897461', 1),
#  ('group);SE.PRM.CMPT.ZS;2006;93.9145965576172', 1),
#  ('(%);SG.GEN.PARL.ZS;2010;10.0', 3),
#  ('(%);SG.GEN.PARL.ZS;1998;10.7', 1),
#  ('Barbados;BRB;Ratio', 2),
#  ('attendance', 1476),
#  ('10-14;SE.ENR.ORPH;1998;', 27),
#  ('resources', 762),
#  ('(cubic', 762),
#  ('Barbados;BRB;Rural', 12),
#  ('(%);SI.POV.RUGP;;', 31),
#  ('(%);SI.POV.RUGP;2003;', 36),
#  ('Barbados;BRB;School', 15),
#  ('net);SE.PRM.NENR;1997;', 14),
#  ('(gross),', 2943),
#  ('gender', 2943),
#  ('(GPI);SE.ENR.PRIM.FM.ZS;2012;', 2),
#  ('(GPI);SE.ENR.PRSC.FM.ZS;2010;1.05471003055573', 1),
#  ('(GPI);SE.ENR.PRSC.FM.ZS;2012;', 4),
#  ('(GPI);SE.ENR.PRSC.FM.ZS;1995;', 4),
#  ('tertiary', 735),
#  ('employed);SL.EMP.SELF.FE.ZS;2006;', 14),
#  ('employed);SL.EMP.SELF.MA.ZS;2014;', 39),
#  ('employed);SL.EMP.SELF.MA.ZS;2013;21.3999996185303', 1),
#  ('employed);SL.EMP.SELF.MA.ZS;1997;15.3999996185303', 1),
#  ('Barbados;BRB;Share', 7),
#  ('wage', 741),
#  ('sector', 1475),
#  ('employment);SL.EMP.INSV.FE.ZS;1999;49.0', 1),
#  ('employment);SL.EMP.INSV.FE.ZS;2005;52.0', 2),
#  ('Barbados;BRB;Status', 6),
#  ('enhanced', 721),
#  ('initiative;DT.HPC.STTS;1990;', 34),
#  ('Barbados;BRB;Terrestrial', 6),
#  ('area);ER.LND.PTLD.ZS;1999;0.124131865378226', 1),
#  ('area);ER.LND.PTLD.ZS;1998;0.124131865378226', 1),
#  ('area);ER.LND.PTLD.ZS;2007;0.124131865378226', 1),
#  ('Barbados;BRB;Total', 13),
#  ('allocable', 734),
#  ('US$);DC.ODA.COMM.SA.CD;1993;', 25),
#  ('US$);DC.ODA.COMM.SA.CD;1992;', 33),
#  ('US$);DC.ODA.COMM.SA.CD;2003;', 27),
#  ('income);DT.TDS.DECT.EX.ZS;2001;', 15),
#  ('GDP);NE.TRD.GNFS.ZS;1995;90.0714364215848', 1),
#  ('Barbados;BRB;Tuberculosis', 15),
#  ('(%,', 696),
#  ('forms);SH.TBS.DTEC.ZS;2010;120.0', 1),
#  ('children);SE.PRM.TENR;2013;85.2088394165039', 1),
#  ('children);SE.PRM.TENR;1993;70.8739700317383', 1),
#  ('children);SE.PRM.TENR;2000;78.4889678955078', 1),
#  ('15-19);SP.ADO.TFRT;1999;54.6595178164145', 1),
#  ('15-19);SP.ADO.TFRT;2006;50.3287663484156', 1),
#  ('World;ARB;Agricultural', 7),
#  ('estimates);SH.DYN.AIDS.DH;1996;', 20),
#  ('estimates);SH.DYN.AIDS.DH;2008;', 21),
#  ('estimates);SH.DYN.AIDS.DH;2009;', 22),
#  ('World;ARB;Antiretroviral', 10),
#  ('HIV);SH.HIV.ARTC.ZS;1994;', 30),
#  ('World;ARB;ARI', 7),
#  ('provider);SH.STA.ARIC.ZS;2005;', 27),
#  ('(%);TM.TAX.AGRI.CD.DV;2011;', 24),
#  ('(%);TM.TAX.AGRI.CD.LD;1996;', 30),
#  ('(%);TM.TAX.CLTH.CD.DV;2000;', 31),
#  ('(%);TM.TAX.CLTH.CD.LD;2002;', 23),
#  ('World;ARB;Bilateral', 20),
#  ('US$);DC.ODA.UNTD.CD;2008;', 30),
#  ('US$);DC.ODA.SOCL.CD;2009;', 31),
#  ('total);SH.STA.BRTC.ZS;2003;', 30),
#  ('World;ARB;Children', 17),
#  ('HIV/AIDS;SH.HIV.ORPH;2012;', 24),
#  ('HIV/AIDS;SH.HIV.ORPH;1996;', 21),
#  ('fever);SH.MLR.TRET.ZS;2004;', 34),
#  ('World;ARB;CO2', 31),
#  ('(kt);EN.ATM.CO2E.KT;2004;1254917.073', 1),
#  ('capita);EN.ATM.CO2E.PC;2011;4.72449969733611', 1),
#  ('capita);EN.ATM.CO2E.PC;2008;4.37357334728226', 1),
#  ('misconceptions);SH.HIV.1524.KW.MA.ZS;2011;', 23),
#  ('misconceptions);SH.HIV.1524.KW.MA.ZS;1993;', 31),
#  ('World;ARB;Condom', 36),
#  ('15-49);SH.CON.AIDS.FE.ZS;2014;', 32),
#  ('15-49);SH.CON.AIDS.MA.ZS;1993;', 36),
#  ('15-49);SH.CON.AIDS.MA.ZS;2004;', 26),
#  ('15-24);SH.CON.1524.FE.ZS;2011;', 33),
#  ('15-24);SH.CON.1524.FE.ZS;1992;', 28),
#  ('World;ARB;Contraceptive', 7),
#  ('15-49);SP.DYN.CONU.ZS;2010;', 27),
#  ('World;ARB;Contributing', 26),
#  ('employed);SL.FAM.WORK.FE.ZS;;', 26),
#  ('employed);SL.FAM.WORK.MA.ZS;2014;', 40),
#  ('employed);SL.FAM.WORK.MA.ZS;2009;', 25),
#  ('employed);SL.FAM.WORK.ZS;2011;', 15),
#  ('employed);SL.FAM.WORK.ZS;1996;', 26),
#  ('employed);SL.FAM.WORK.ZS;2004;', 12),
#  ('terms;DT.HPC.COMR.PV;2012;', 17),
#  ('terms;DT.HPC.COMR.PV;1998;', 35),
#  ('income);DT.TDS.DPPF.XP.ZS;2014;', 26),
#  ('estimate);SL.EMP.1524.SP.FE.ZS;1994;11.5456676994517', 1),
#  ('estimate);SL.EMP.1524.SP.MA.ZS;1997;40.1655034921291', 1),
#  ('PPP);EG.USE.COMM.GD.PP.KD;2010;117.524272986493', 1),
#  ('woman);SP.DYN.TFRT.IN;2012;3.23334132712482', 1),
#  ('area);AG.LND.FRST.ZS;2005;3.45481825192928', 1),
#  ('km);AG.LND.FRST.K2;2002;891573.2', 1),
#  ('$);SL.GDP.PCAP.EM.KD;1991;12039.6773719464', 1),
#  ('$);SL.GDP.PCAP.EM.KD;1994;11952.19892891', 1),
#  ('US$);NY.GNP.PCAP.CD;1995;2114.89867268213', 1),
#  ('US$);NY.GNP.PCAP.CD;2006;4068.57963915509', 1),
#  ('US$);NY.GNP.PCAP.CD;2004;3004.05466342653', 1),
#  ('Greenland;GRL;Average', 6),
#  ('(%);TM.TAX.CLTH.CD.LD;2014;', 26),
#  ('(%);TM.TAX.TXTL.CD.DV;1993;', 30),
#  ('(%);TM.TAX.TXTL.CD.DV;2003;', 29),
#  ('(%);TM.TAX.TXTL.CD.DV;2000;', 35),
#  ('Greenland;GRL;Bilateral', 4),
#  ('commitments);DC.ODA.UNTD.ZS;2010;', 36),
#  ('commitments);DC.ODA.UNTD.ZS;2012;', 27),
#  ('commitments);DC.ODA.UNTD.ZS;1991;', 36),
#  ('Greenland;GRL;Bilateral,', 2),
#  ('US$);DC.ODA.SOCL.CD;1999;', 28),
#  ('Greenland;GRL;Children', 2),
#  ('Greenland;GRL;CO2', 7),
#  ('GDP);EN.ATM.CO2E.PP.GD;2003;', 3),
#  ('(kt);EN.ATM.CO2E.KT;1991;550.05', 1),
#  ('(kt);EN.ATM.CO2E.KT;2003;531.715', 1),
#  ('(kt);EN.ATM.CO2E.KT;2007;638.058', 1),
#  ('misconceptions);SH.HIV.1524.KW.FE.ZS;2000;', 28),
#  ('15-24);SH.CON.1524.FE.ZS;2012;', 30),
#  ('15-24);SH.CON.1524.FE.ZS;2009;', 17),
#  ('15-24);SH.CON.1524.MA.ZS;2008;', 27),
#  ('Greenland;GRL;Contributing', 10),
#  ('employed);SL.FAM.WORK.FE.ZS;1999;', 24),
#  ('employed);SL.FAM.WORK.ZS;1995;', 18),
#  ('employed);SL.FAM.WORK.ZS;2007;', 18),
#  ('employed);SL.FAM.WORK.ZS;2005;', 18),
#  ('Greenland;GRL;Debt', 10),
#  ('terms;DT.HPC.COMR.PV;1994;', 35),
#  ('terms;DT.HPC.COMR.PV;2008;', 33),
#  ('terms;DT.HPC.MDRI.PV;1994;', 25),
#  ('income);DT.TDS.DPPF.XP.ZS;1999;', 20),
#  ('income);DT.TDS.DPPF.XP.ZS;2000;', 21),
#  ('Greenland;GRL;Employment', 11),
#  ('estimate);SL.EMP.TOTL.SP.FE.ZS;2013;', 4),
#  ('estimate);SL.EMP.TOTL.SP.MA.ZS;2010;', 2),
#  ('estimate);SL.EMP.TOTL.SP.MA.ZS;2012;', 3),
#  ('estimate);SL.EMP.TOTL.SP.MA.ZS;1999;', 4),
#  ('estimate);SL.EMP.TOTL.SP.ZS;2012;', 3),
#  ('estimate);SL.EMP.TOTL.SP.ZS;1994;', 3),
#  ('estimate);SL.EMP.1524.SP.FE.ZS;1990;', 32),
#  ('estimate);SL.EMP.1524.SP.FE.ZS;1996;', 5),
#  ('estimate);SL.EMP.1524.SP.ZS;1990;', 20),
#  ('estimate);SL.EMP.1524.SP.ZS;1992;', 5),
#  ('Greenland;GRL;Fertility', 2),
#  ('woman);SP.DYN.TFRT.IN;1991;2.41', 1),
#  ('people);IT.MLT.MAIN.P2;1999;45.7046512872665', 1),
#  ('Greenland;GRL;Forest', 8),
#  ('Ghana;GHA;Total', 6),
#  ('income);DT.TDS.DECT.EX.ZS;1996;25.3769639490373', 1),
#  ('Ghana;GHA;Trade', 6),
#  ('GDP);NE.TRD.GNFS.ZS;2011;86.1865151923779', 1),
#  ('GDP);NE.TRD.GNFS.ZS;1991;42.4883492637987', 1),
#  ('Ghana;GHA;Tuberculosis', 11),
#  ('forms);SH.TBS.DTEC.ZS;1999;36.0', 1),
#  ('people);SH.TBS.MORT;;', 29),
#  ('people);SH.TBS.MORT;1993;41.0', 1),
#  ('people);SH.TBS.MORT;1998;33.0', 1),
#  ('people);SH.TBS.MORT;2004;22.0', 2),
#  ('cases);SH.TBS.CURE.ZS;2000;50.0', 1),
#  ('cases);SH.TBS.CURE.ZS;2005;61.0', 1),
#  ('Ghana;GHA;Unmet', 5),
#  ('15-49);SP.UWT.TFRT;1998;', 27),
#  ('15-49);SP.UWT.TFRT;2002;', 30),
#  ('15-49);SP.UWT.TFRT;2005;', 23),
#  ('15-49);SP.UWT.TFRT;2009;', 32),
#  ('(%);SI.POV.URGP;1993;', 24),
#  ('children);SE.PRM.TENR;1995;72.5433731079102', 1),
#  ('GDP);NY.AGR.SUBS.GD.ZS;1992;', 24),
#  ('HIV);SH.HIV.ARTC.ZS;2002;0.481378026070764', 1),
#  ('provider);SH.STA.ARIC.ZS;2011;', 21),
#  ('(%);TM.TAX.CLTH.CD.DV;2011;', 29),
#  ('(%);TM.TAX.TXTL.CD.DV;1999;', 31),
#  ('(%);TM.TAX.TXTL.CD.LD;2001;', 28),
#  ('commitments);DC.ODA.UNTD.ZS;;', 28),
#  ('commitments);DC.ODA.UNTD.ZS;2005;', 26),
#  ('commitments);DC.ODA.UNTD.ZS;2008;', 22),
#  ('US$);DC.ODA.UNTD.CD;2002;', 29),
#  ('US$);DC.ODA.UNTD.CD;2009;', 33),
#  ('total);SH.STA.BRTC.ZS;1996;', 21),
#  ('total);SH.STA.BRTC.ZS;1998;', 19),
#  ('HIV/AIDS;SH.HIV.ORPH;1997;', 22),
#  ('HIV/AIDS;SH.HIV.ORPH;2006;', 32),
#  ('fever);SH.MLR.TRET.ZS;2014;', 22),
#  ('fever);SH.MLR.TRET.ZS;2013;', 33),
#  ('fever);SH.MLR.TRET.ZS;1993;', 34),
#  ('fever);SH.MLR.TRET.ZS;1996;', 24),
#  ('fever);SH.MLR.TRET.ZS;2008;', 37),
#  ('GDP);EN.ATM.CO2E.PP.GD;1990;0.493995820386132', 1),
#  ('GDP);EN.ATM.CO2E.PP.GD;1994;0.520979603599031', 1),
#  ('GDP);EN.ATM.CO2E.PP.GD;2008;0.320988642357814', 1),
#  ('capita);EN.ATM.CO2E.PC;2005;4.20678891094678', 1),
#  ('misconceptions);SH.HIV.1524.KW.FE.ZS;2007;', 24),
#  ('15-49);SH.CON.AIDS.MA.ZS;2006;', 26),
#  ('15-49);SH.CON.AIDS.MA.ZS;2007;', 34),
#  ('15-49);SP.DYN.CONU.ZS;2008;', 22),
#  ('employed);SL.FAM.WORK.MA.ZS;1991;', 23),
#  ('employed);SL.FAM.WORK.ZS;;', 27),
#  ('employed);SL.FAM.WORK.ZS;2006;', 20),
#  ('terms;DT.HPC.TOTL.PV;2001;', 29),
#  ('income);DT.TDS.DPPF.XP.ZS;1992;', 20),
#  ('estimate);SL.EMP.TOTL.SP.ZS;1993;42.1561887415627', 1),
#  ('estimate);SL.EMP.TOTL.SP.ZS;1995;42.3528163907206', 1),
#  ('estimate);SL.EMP.1524.SP.FE.ZS;2001;10.520055171736', 1),
#  ('estimate);SL.EMP.1524.SP.FE.ZS;2007;10.9933340783633', 1),
#  ('estimate);SL.EMP.1524.SP.ZS;2012;23.4656956188284', 1),
#  ('estimate);SL.EMP.1524.SP.ZS;2006;24.8779843463325', 1),
#  ('PPP);EG.USE.COMM.GD.PP.KD;1991;108.902720544975', 1),
#  ('woman);SP.DYN.TFRT.IN;1992;4.84105232715768', 1),
#  ('area);AG.LND.FRST.ZS;2012;2.85632230023747', 1),
#  ('area);AG.LND.FRST.ZS;1998;3.54844692946886', 1),
#  ('Central', 3519),
#  ('Asia', 4831),
#  ('(developing', 5883),
#  ('cohort);SE.PRM.PRSL.FE.ZS;2000;95.4377670288086', 1),
#  ('cohort);SE.PRM.PRSL.FE.ZS;2008;95.9939422607422', 1),
#  ('cohort);SE.PRM.PRSL.ZS;2002;96.2080078125', 1),
#  ('total;SP.POP.TOTL;1995;243052945.0', 1),
#  ('only);ECA;Poverty', 46),
#  ('(%);SI.POV.GAPS;1992;', 26),
#  ('(%);SI.POV.GAPS;2009;', 23),
#  ('(%);SI.POV.NAGP;;', 29),
#  ('population);SI.POV.DDAY;1995;', 24),
#  ('population);SI.POV.2DAY;2010;7.05', 1),
#  ('only);ECA;PPP', 23),
#  ('$);PA.NUS.PPP;2006;', 13),
#  ('$);PA.NUS.PPP;2008;', 8),
#  ('$);PA.NUS.PRVT.PP;1992;', 16),
#  ('$);PA.NUS.PRVT.PP;2007;', 15),
#  ('women);SH.STA.ANV4.ZS;2005;', 28),
#  ('15-24);SH.HIV.1524.FE.ZS;1992;', 14),
#  ('15-24);SH.HIV.1524.MA.ZS;1991;', 9),
#  ('15-49);SH.DYN.AIDS.ZS;2003;', 13),
#  ('5);SH.STA.MALN.ZS;;', 35),
#  ('5);SH.STA.MALN.ZS;2008;', 29),
#  ('only);ECA;Proportion', 9),
#  ('10-14;SE.ENR.ORPH;1993;', 30),
#  ('meters);ER.H2O.INTR.PC;1992;3113.86730572485', 1),
#  ('only);ECA;Rural', 18),
#  ('(%);SI.POV.RUGP;1996;', 31),
#  ('net);SE.PRM.NENR;2011;93.1298522949219', 1),
#  ('net);SE.PRM.NENR;1998;90.2554092407227', 1),
#  ('(GPI);SE.ENR.SECO.FM.ZS;1990;0.934130012989044', 1),
#  ('(GPI);SE.ENR.SECO.FM.ZS;1993;0.934400022029877', 1),
#  ('only);ECA;Self-employed,', 23),
#  ('employed);SL.EMP.SELF.ZS;1995;', 18),
#  ('employment);SL.EMP.INSV.FE.ZS;1997;41.614156855028', 1),
#  ('employment);SL.EMP.INSV.FE.ZS;1996;40.5683433957535', 1),
#  ('only);ECA;Status', 8),
#  ('initiative;DT.HPC.STTS;1996;', 24),
#  ('area);ER.LND.PTLD.ZS;2014;', 24),
#  ('area);ER.LND.PTLD.ZS;1996;3.11208225784534', 1),
#  ('only);ECA;Total', 25),
#  ('US$);DC.ODA.COMM.CD;2009;', 34),
#  ('income);DT.TDS.DECT.EX.ZS;1992;', 25),
#  ('only);ECA;Tuberculosis', 29),
#  ('forms);SH.TBS.DTEC.ZS;1998;48.0', 1),
#  ('people);SH.TBS.MORT;1993;9.0', 1),
#  ('people);SH.TBS.MORT;2000;14.0', 1),
#  ('cases);SH.TBS.CURE.ZS;2004;82.0', 1),
#  ('only);ECA;Unmet', 7),
#  ('only);ECA;Urban', 15),
#  ('(%);SI.POV.URGP;2002;', 35),
#  ('Mariana', 199),
#  ('US$);NY.GNP.PCAP.CD;2014;', 6),
#  ('US$);NY.GNP.PCAP.CD;2012;', 3),
#  ('arms);TM.MRC.NOTX.LD.ZS;2008;', 27),
#  ('GDP);NE.GDI.TOTL.ZS;1996;', 5),
#  ('Islands;MNP;Immunization,', 2),
#  ('months);SH.IMM.MEAS;2013;', 1),
#  ('months);SH.IMM.MEAS;1991;', 5),
#  ('access);SH.STA.ACSN;2001;74.2', 1),
#  ('access);SH.H2O.SAFE.ZS;1990;94.0', 1),
#  ('people);SH.TBS.INCD;1999;113.0', 1),
#  ('Islands;MNP;Income', 4),
#  ('20%;SI.DST.FRST.20;2012;', 20),
#  ('20%;SI.DST.FRST.20;2003;', 23),
#  ('people);IT.NET.USER.P2;2012;', 1),
#  ('people);IT.NET.USER.P2;2003;', 2),
#  ('people);IT.NET.USER.P2;2000;', 2),
#  ('Islands;MNP;Literacy', 7),
#  ('15-24);SE.ADT.1524.LT.FE.ZS;1990;', 22),
#  ('15-24);SE.ADT.1524.LT.FE.ZS;2008;', 28),
#  ('15-24);SE.ADT.1524.LT.MA.ZS;1990;', 21),
#  ('Islands;MNP;Malaria', 3),
#  ('reported;SH.STA.MALR;2008;', 21),
#  ('Islands;MNP;Marine', 2),
#  ('waters);ER.MRN.PTMR.ZS;1999;0.0224335284359796', 1),
#  ('waters);ER.MRN.PTMR.ZS;2004;0.0618075988017343', 1),
#  ('births);SH.STA.MMRT;2001;', 3),
#  ('people);IT.CEL.SETS.P2;2013;', 1),
#  ('people);IT.CEL.SETS.P2;2007;', 4),
#  ('people);IT.CEL.SETS.P2;2005;', 3),
#  ('Islands;MNP;Mortality', 2),
#  ('births);SP.DYN.IMRT.IN;2011;', 2),
#  ('births);SH.DYN.MORT;1995;', 5),
#  ('GNI);DC.ODA.TLDC.GN.ZS;;', 31),
#  ('GNI);DC.ODA.TLDC.GN.ZS;1996;', 32),
#  ('GNI);DC.ODA.TLDC.GN.ZS;2008;', 24),
#  ('GNI);DC.ODA.TOTL.GN.ZS;2010;', 31),
#  ('US$);DC.ODA.TOTL.KD;1993;', 33),
#  ('US$);DC.ODA.TOTL.KD;2001;', 29),
#  ('US$);DC.ODA.TOTL.KD;2006;', 34),
#  ('US$);DC.ODA.TOTL.KD;2008;', 29),
#  ('US$);DC.ODA.TOTL.CD;1998;', 26),
#  ('US$);DC.ODA.TOTL.CD;2007;', 28),
#  ('GNI);DT.ODA.ODAT.GN.ZS;2013;', 9),
#  ('GNI);DT.ODA.ODAT.GN.ZS;1999;', 8),
#  ('GNI);DT.ODA.ODAT.GN.ZS;2009;', 4),
#  ('US$);DT.ODA.ODAT.PC.ZS;1996;-26.0589563139025', 1),
#  ('US$);DT.ODA.ODAT.PC.ZS;1999;1.78382958481366', 1),
#  ('US$);DT.ODA.ODAT.CD;2013;', 7),
#  ('US$);DT.ODA.ODAT.CD;1995;-700000.0', 1),
#  ('US$);DT.ODA.ODAT.CD;2002;', 7),
#  ('Islands;MNP;Percentage', 3),
#  ('(%);SH.HIV.KNOW.FE.ZS;2014;', 25),
#  ('(%);SH.HIV.KNOW.FE.ZS;1995;', 27),
#  ('(%);SH.HIV.KNOW.MA.ZS;2012;', 32),
#  ('Islands;MNP;Persistence', 7),
#  ('cohort);SE.PRM.PRSL.FE.ZS;1998;', 17),
#  ('cohort);SE.PRM.PRSL.ZS;1995;', 15),
#  ('cohort);SE.PRM.PRSL.ZS;2003;', 10),
#  ('population);EN.POP.SLUM.UR.ZS;1996;', 33),
#  ('population);EN.POP.SLUM.UR.ZS;1999;', 25),
#  ('total;SP.POP.TOTL;1994;54817.0', 1),
#  ('total;SP.POP.TOTL;1999;67271.0', 1),
#  ('total;SP.POP.TOTL;2007;59791.0', 1),
#  ('(%);SI.POV.GAPS;1998;', 27),
#  ('Lesotho;LSO;Contraceptive', 4),
#  ('Lesotho;LSO;Contributing', 5),
#  ('employed);SL.FAM.WORK.FE.ZS;1990;', 27),
#  ('employed);SL.FAM.WORK.FE.ZS;2001;', 12),
#  ('employed);SL.FAM.WORK.MA.ZS;2001;', 12),
#  ('employed);SL.FAM.WORK.ZS;1990;', 31),
#  ('terms;DT.HPC.MDRI.PV;2000;', 25),
#  ('income);DT.TDS.DPPF.XP.ZS;2007;5.90436861335948', 1),
#  ('Lesotho;LSO;Employment', 12),
#  ('estimate);SL.EMP.TOTL.SP.MA.ZS;1999;63.9000015258789', 1),
#  ('estimate);SL.EMP.TOTL.SP.ZS;2008;48.9000015258789', 1),
#  ('estimate);SL.EMP.1524.SP.FE.ZS;2004;20.7000007629395', 2),
#  ('estimate);SL.EMP.1524.SP.MA.ZS;2012;38.0', 1),
#  ('estimate);SL.EMP.1524.SP.ZS;2006;29.7000007629395', 1),
#  ('estimate);SL.EMP.1524.SP.ZS;2005;28.6000003814697', 1),
#  ('Lesotho;LSO;Fertility', 1),
#  ('Lesotho;LSO;Forest', 2),
#  ('km);AG.LND.FRST.K2;2002;424.0', 1),
#  ('$);SL.GDP.PCAP.EM.KD;2012;', 8),
#  ('equivalent);EG.GDP.PUSE.KO.PP.KD;1991;', 18),
#  ('Lesotho;LSO;GNI,', 2),
#  ('US$);NY.GNP.ATLS.CD;2006;1907882520.10351', 1),
#  ('Lesotho;LSO;Goods', 4),
#  ('arms);TM.MRC.NOTX.DV.ZS;1997;', 30),
#  ('arms);TM.MRC.NOTX.DV.ZS;1996;', 19),
#  ('months);SH.IMM.MEAS;2001;70.0', 2),
#  ('Lesotho;LSO;Improved', 4),
#  ('Lesotho;LSO;Incidence', 1),
#  ('people);SH.TBS.INCD;1991;317.0', 1),
#  ('Lesotho;LSO;Income', 2),
#  ('15-24);SE.ADT.1524.LT.FE.ZS;1991;', 22),
#  ('Lesotho;LSO;Malaria', 3),
#  ('reported;SH.STA.MALR;2002;', 19),
#  ('waters);ER.MRN.PTMR.ZS;1997;', 10),
#  ('waters);ER.MRN.PTMR.ZS;1999;', 12),
#  ('Lesotho;LSO;Maternal', 5),
#  ('births);SH.STA.MMRT;1994;522.0', 1),
#  ('births);SH.STA.MMRT;1998;586.0', 1),
#  ('Lesotho;LSO;Mobile', 2),
#  ('people);IT.CEL.SETS.P2;2010;49.1531523638809', 1),
#  ('Lesotho;LSO;Mortality', 1),
#  ('US$);DC.ODA.TLDC.CD;1997;', 30),
#  ('US$);DC.ODA.TOTL.CD;1996;', 25),
#  ('GNI);DT.ODA.ODAT.GN.ZS;1998;5.64804190472061', 1),
#  ('US$);DT.ODA.ALLD.CD;1992;143160000.0', 1),
#  ('US$);DT.ODA.ALLD.CD;2007;128790000.0', 1),
#  ('US$);DT.ODA.ODAT.CD;2003;78870000.0', 1),
#  ('Lesotho;LSO;Percentage', 6),
#  ('(%);SH.HIV.KNOW.FE.ZS;2006;', 28),
#  ('(%);SH.HIV.KNOW.FE.ZS;2004;25.8', 1),
#  ('(%);SH.HIV.KNOW.MA.ZS;1991;', 22),
#  ('(%);SH.HIV.KNOW.MA.ZS;1997;', 30),
#  ('Lesotho;LSO;Persistence', 5),
#  ('cohort);SE.PRM.PRSL.FE.ZS;2011;75.0746612548828', 1),
#  ('cohort);SE.PRM.PRSL.FE.ZS;2000;62.9006118774414', 1),
#  ('cohort);SE.PRM.PRSL.MA.ZS;2004;49.2346496582031', 1),
#  ('cohort);SE.PRM.PRSL.ZS;2009;69.2980728149414', 1),
#  ('Lesotho;LSO;Population', 3),
#  ('Lesotho;LSO;Population,', 4),
#  ('total;SP.POP.TOTL;2011;2032950.0', 1),
#  ('total;SP.POP.TOTL;2006;1940345.0', 1),
#  ('total;SP.POP.TOTL;2009;1990413.0', 1),
#  ('Ecuador;ECU;Self-employed,', 22),
#  ('employed);SL.EMP.SELF.FE.ZS;2006;56.4000015258789', 1),
#  ('employed);SL.EMP.SELF.MA.ZS;1992;41.9000015258789', 1),
#  ('employed);SL.EMP.SELF.MA.ZS;2001;44.7999992370605', 1),
#  ('employed);SL.EMP.SELF.MA.ZS;2005;43.7000007629395', 1),
#  ('employed);SL.EMP.SELF.ZS;2011;47.4000015258789', 1),
#  ('employed);SL.EMP.SELF.ZS;1994;42.0', 1),
#  ('Ecuador;ECU;Share', 7),
#  ('employment);SL.EMP.INSV.FE.ZS;1999;39.0', 1),
#  ('Ecuador;ECU;Status', 6),
#  ('Ecuador;ECU;Terrestrial', 7),
#  ('Ecuador;ECU;Total', 20),
#  ('US$);DC.ODA.COMM.CD;1996;', 27),
#  ('US$);DC.ODA.COMM.SA.CD;2010;', 23),
#  ('income);DT.TDS.DECT.EX.ZS;2003;32.7366239230857', 1),
#  ('Ecuador;ECU;Trade', 7),
#  ('GDP);NE.TRD.GNFS.ZS;2002;49.3765496413265', 1),
#  ('Ecuador;ECU;Tuberculosis', 20),
#  ('people);SH.TBS.MORT;1999;15.0', 1),
#  ('cases);SH.TBS.CURE.ZS;1992;', 26),
#  ('cases);SH.TBS.CURE.ZS;2001;71.0', 3),
#  ('15-49);SP.UWT.TFRT;2014;', 27),
#  ('15-49);SP.UWT.TFRT;2004;7.4', 1),
#  ('Ecuador;ECU;Vulnerable', 14),
#  ('children);SE.PRM.TENR;2008;', 8),
#  ('Rep.;EGY;Adolescent', 3),
#  ('GDP);NY.AGR.SUBS.GD.ZS;2008;', 29),
#  ('resources);ER.H2O.FWTL.ZS;1998;', 30),
#  ('Rep.;EGY;Antiretroviral', 6),
#  ('HIV);SH.HIV.ARTC.ZS;2006;5.0', 2),
#  ('(%);TM.TAX.AGRI.CD.DV;2014;', 37),
#  ('(%);TM.TAX.CLTH.CD.DV;2009;', 23),
#  ('(%);TM.TAX.CLTH.CD.LD;2003;', 20),
#  ('(%);TM.TAX.TXTL.CD.DV;2014;', 35),
#  ('(%);TM.TAX.TXTL.CD.DV;;', 21),
#  ('(%);TM.TAX.TXTL.CD.DV;2006;', 25),
#  ('(%);TM.TAX.TXTL.CD.LD;1999;', 23),
#  ('Rep.;EGY;Bilateral', 20),
#  ('Rep.;EGY;Bilateral,', 13),
#  ('US$);DC.ODA.SOCL.CD;2002;', 33),
#  ('Rep.;EGY;Births', 9),
#  ('total);SH.STA.BRTC.ZS;1990;', 22),
#  ('total);SH.STA.BRTC.ZS;1993;', 20),
#  ('total);SH.STA.BRTC.ZS;1992;40.7', 1),
#  ('Rep.;EGY;Children', 22),
#  ('GDP);EN.ATM.CO2E.PP.GD;2003;0.312063330440338', 1),
#  ('GDP);EN.ATM.CO2E.PP.GD;2001;0.28945634401006', 1),
#  ('GDP);EN.ATM.CO2E.PP.GD;2006;0.296596512477638', 1),
#  ('Rep.;EGY;Comprehensive', 14),
#  ('Rep.;EGY;Condom', 39),
#  ('15-49);SH.CON.AIDS.FE.ZS;2013;', 34),
#  ('population);SI.POV.2DAY;;', 28),
#  ('population);SI.POV.2DAY;2007;', 29),
#  ('population);SI.POV.NAHC;2000;', 24),
#  ('population);SI.POV.NAHC;2006;', 33),
#  ('Guam;GUM;PPP', 4),
#  ('$);PA.NUS.PRVT.PP;2014;', 7),
#  ('Guam;GUM;Pregnant', 9),
#  ('(%);SH.STA.ANVC.ZS;2013;', 29),
#  ('women);SH.STA.ANV4.ZS;;', 27),
#  ('women);SH.STA.ANV4.ZS;1993;', 26),
#  ('Guam;GUM;Prevalence', 27),
#  ('5);SH.STA.MALN.ZS;1998;', 31),
#  ('Guam;GUM;Primary', 6),
#  ('group);SE.PRM.CMPT.ZS;1994;', 8),
#  ('group);SE.PRM.CMPT.ZS;2007;', 5),
#  ('Guam;GUM;Ratio', 3),
#  ('Guam;GUM;Renewable', 3),
#  ('population);SI.POV.RUHC;2011;', 22),
#  ('population);SI.POV.RUHC;2013;', 22),
#  ('(GPI);SE.ENR.PRSC.FM.ZS;1992;', 9),
#  ('(GPI);SE.ENR.PRSC.FM.ZS;1994;', 13),
#  ('(GPI);SE.ENR.PRSC.FM.ZS;2000;', 7),
#  ('(GPI);SE.ENR.PRSC.FM.ZS;2008;', 9),
#  ('Guam;GUM;Self-employed,', 13),
#  ('employed);SL.EMP.SELF.FE.ZS;;', 39),
#  ('employed);SL.EMP.SELF.FE.ZS;1991;', 17),
#  ('employed);SL.EMP.SELF.FE.ZS;1990;', 22),
#  ('employed);SL.EMP.SELF.MA.ZS;2013;', 24),
#  ('initiative;DT.HPC.STTS;2002;', 24),
#  ('Guam;GUM;Terrestrial', 6),
#  ('Guam;GUM;Total', 15),
#  ('income);DT.TDS.DECT.EX.ZS;1995;', 12),
#  ('income);DT.TDS.DECT.EX.ZS;1998;', 18),
#  ('income);DT.TDS.DECT.EX.ZS;2009;', 15),
#  ('GDP);NE.TRD.GNFS.ZS;2012;', 3),
#  ('Guam;GUM;Tuberculosis', 14),
#  ('forms);SH.TBS.DTEC.ZS;;', 22),
#  ('Grenada;GRD;Ratio', 3),
#  ('Grenada;GRD;Renewable', 10),
#  ('meters);ER.H2O.INTR.PC;1999;', 24),
#  ('Grenada;GRD;Rural', 10),
#  ('(%);SI.POV.RUGP;1997;', 23),
#  ('Grenada;GRD;School', 13),
#  ('(GPI);SE.ENR.TERT.FM.ZS;2005;', 7),
#  ('Grenada;GRD;Self-employed,', 11),
#  ('employed);SL.EMP.SELF.FE.ZS;2005;', 12),
#  ('employed);SL.EMP.SELF.MA.ZS;1998;24.6000003814697', 1),
#  ('employed);SL.EMP.SELF.ZS;2004;', 16),
#  ('area);ER.LND.PTLD.ZS;2004;1.6714071307708', 1),
#  ('Grenada;GRD;Total', 21),
#  ('US$);DC.ODA.COMM.CD;2000;', 26),
#  ('US$);DC.ODA.COMM.SA.CD;2013;', 30),
#  ('income);DT.TDS.DECT.EX.ZS;2011;12.6218019337647', 1),
#  ('income);DT.TDS.DECT.EX.ZS;2007;8.84027318661665', 1),
#  ('forms);SH.TBS.DTEC.ZS;1991;23.0', 2),
#  ('forms);SH.TBS.DTEC.ZS;1995;89.0', 2),
#  ('people);SH.TBS.MORT;2004;1.0', 1),
#  ('cases);SH.TBS.CURE.ZS;2007;100.0', 1),
#  ('population);SI.POV.2DAY;2012;', 20),
#  ('population);SI.POV.NAHC;1999;', 28),
#  ('World;ARB;PPP', 20),
#  ('$);PA.NUS.PPP;1996;', 18),
#  ('World;ARB;Pregnant', 19),
#  ('(%);SH.STA.ANVC.ZS;2003;', 28),
#  ('women);SH.STA.ANV4.ZS;2010;', 32),
#  ('women);SH.STA.ANV4.ZS;2003;', 26),
#  ('World;ARB;Prevalence', 35),
#  ('15-24);SH.HIV.1524.MA.ZS;1995;0.107796158530077', 1),
#  ('population);SN.ITK.DEFC.ZS;2009;9.51374861967621', 1),
#  ('5);SH.STA.MALN.ZS;1992;', 33),
#  ('5);SH.STA.MALN.ZS;2003;', 27),
#  ('group);SE.PRM.CMPT.ZS;1997;75.0539703369141', 1),
#  ('World;ARB;Proportion', 10),
#  ('10-14;SE.ENR.ORPH;1994;', 25),
#  ('World;ARB;Renewable', 11),
#  ('World;ARB;Rural', 22),
#  ('(%);SI.POV.RUGP;1998;', 35),
#  ('(%);SI.POV.RUGP;2002;', 19),
#  ('(%);SI.POV.RUGP;2009;', 34),
#  ('population);SI.POV.RUHC;1999;', 30),
#  ('population);SI.POV.RUHC;2000;', 30),
#  ('World;ARB;School', 38),
#  ('net);SE.PRM.NENR;2002;79.8812408447266', 1),
#  ('(GPI);SE.ENR.PRSC.FM.ZS;1998;0.854910016059875', 1),
#  ('(GPI);SE.ENR.SECO.FM.ZS;2013;0.936429977416992', 1),
#  ('(GPI);SE.ENR.SECO.FM.ZS;2008;0.93503999710083', 1),
#  ('(GPI);SE.ENR.TERT.FM.ZS;2004;0.920459985733032', 1),
#  ('employed);SL.EMP.SELF.FE.ZS;2013;', 29),
#  ('children);SE.PRM.TENR;2011;85.3645477294922', 1),
#  ('children);SE.PRM.TENR;1998;76.3016967773438', 1),
#  ('15-19);SP.ADO.TFRT;2011;49.5798955308514', 1),
#  ('estimates);SH.DYN.AIDS.DH;1990;', 19),
#  ('resources);ER.H2O.FWTL.ZS;2014;', 26),
#  ('resources);ER.H2O.FWTL.ZS;2003;', 23),
#  ('HIV);SH.HIV.ARTC.ZS;;', 23),
#  ('HIV);SH.HIV.ARTC.ZS;2006;2.93923480870218', 1),
#  ('HIV);SH.HIV.ARTC.ZS;2008;5.64961457603364', 1),
#  ('provider);SH.STA.ARIC.ZS;2001;', 29),
#  ('(%);TM.TAX.AGRI.CD.DV;2012;', 23),
#  ('(%);TM.TAX.TXTL.CD.LD;2008;', 25),
#  ('commitments);DC.ODA.UNTD.ZS;1990;', 27),
#  ('US$);DC.ODA.UNTD.CD;1991;', 27),
#  ('US$);DC.ODA.UNTD.CD;1990;', 25),
#  ('commitments);DC.ODA.SOCL.ZS;2010;', 34),
#  ('total);SH.STA.BRTC.ZS;2011;77.6463270969101', 1),
#  ('total);SH.STA.BRTC.ZS;1994;', 26),
#  ('HIV/AIDS;SH.HIV.ORPH;1990;', 22),
#  ('commitments);DC.ODA.UNTD.ZS;2014;', 26),
#  ('commitments);DC.ODA.UNTD.ZS;2011;', 22),
#  ('commitments);DC.ODA.UNTD.ZS;1992;', 31),
#  ('commitments);DC.ODA.UNTD.ZS;1998;', 30),
#  ('Comoros;COM;Bilateral,', 10),
#  ('Comoros;COM;Children', 14),
#  ('Comoros;COM;CO2', 21),
#  ('capita);EN.ATM.CO2E.PC;1993;0.169922857622002', 1),
#  ('Comoros;COM;Condom', 21),
#  ('15-49);SH.CON.AIDS.FE.ZS;2002;', 36),
#  ('15-24);SH.CON.1524.MA.ZS;1993;', 30),
#  ('Comoros;COM;Contraceptive', 3),
#  ('15-49);SP.DYN.CONU.ZS;2006;', 25),
#  ('15-49);SP.DYN.CONU.ZS;2005;', 21),
#  ('employed);SL.FAM.WORK.FE.ZS;2004;', 18),
#  ('employed);SL.FAM.WORK.MA.ZS;1990;', 28),
#  ('employed);SL.FAM.WORK.ZS;2009;', 20),
#  ('Comoros;COM;Debt', 23),
#  ('terms;DT.HPC.TOTL.PV;1991;', 31),
#  ('terms;DT.HPC.COMR.PV;2013;', 34),
#  ('terms;DT.HPC.MDRI.PV;1998;', 26),
#  ('Comoros;COM;Employment', 32),
#  ('estimate);SL.EMP.TOTL.SP.MA.ZS;2008;74.9000015258789', 1),
#  ('estimate);SL.EMP.TOTL.SP.ZS;2000;51.0', 2),
#  ('PPP);EG.USE.COMM.GD.PP.KD;1997;', 8),
#  ('woman);SP.DYN.TFRT.IN;1997;5.27', 1),
#  ('woman);SP.DYN.TFRT.IN;1999;5.306', 1),
#  ('cohort);SE.PRM.PRSL.MA.ZS;2014;', 27),
#  ('cohort);SE.PRM.PRSL.MA.ZS;1997;', 25),
#  ('population);EN.POP.SLUM.UR.ZS;2014;', 26),
#  ('population);EN.POP.SLUM.UR.ZS;1995;26.8', 1),
#  ('population);EN.POP.SLUM.UR.ZS;2005;17.9', 1),
#  ('Colombia;COL;Poverty', 40),
#  ('(%);SI.POV.GAPS;1999;10.59', 1),
#  ('(%);SI.POV.GAP2;;', 30),
#  ('population);SI.POV.DDAY;2005;10.4', 1),
#  ('population);SI.POV.2DAY;1997;', 28),
#  ('population);SI.POV.NAHC;2009;40.3', 1),
#  ('Colombia;COL;PPP', 9),
#  ...]

# %%
#textFile.first() # returns first item
textFile.take(3)
# Out:
# ['Country Name;Country Code;Indicator Name;Indicator Code;Year;Value',
#  'Grenada;GRD;Malaria cases reported;SH.STA.MALR;1998;',
#  'Grenada;GRD;Malaria cases reported;SH.STA.MALR;2000;']

# %%
lines = textFile.map(lambda x: (x.split(',')))

# %%
lines.take(3)
# Out:
# [['Country Name;Country Code;Indicator Name;Indicator Code;Year;Value'],
#  ['Grenada;GRD;Malaria cases reported;SH.STA.MALR;1998;'],
#  ['Grenada;GRD;Malaria cases reported;SH.STA.MALR;2000;']]

# %%
#get Year
years = lines.map(lambda x: (x[0].split(';')[4], 1))
print(years.take(3))

counts = years.reduceByKey(lambda a, b: a + b)
print(counts.collect()) # TODO: fix it
# Out:
# [('Year', 1), ('1998', 1), ('2000', 1)]
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-116-c40cb38582e2> in <module>()
#       4
#       5 counts = years.reduceByKey(lambda a, b: a + b)
# ----> 6 print(counts.collect())
#
# C:\spark\python\pyspark\rdd.py in collect(self)
#     806         """
#     807         with SCCallSiteSync(self.context) as css:
# --> 808             port = self.ctx._jvm.PythonRDD.collectAndServe(self._jrdd.rdd())
#     809         return list(_load_from_socket(port, self._jrdd_deserializer))
#     810
#
# c:\python\lib\site-packages\py4j\java_gateway.py in __call__(self, *args)
#    1131         answer = self.gateway_client.send_command(command)
#    1132         return_value = get_return_value(
# -> 1133             answer, self.gateway_client, self.target_id, self.name)
#    1134
#    1135         for temp_arg in temp_args:
#
# c:\python\lib\site-packages\py4j\protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     317                 raise Py4JJavaError(
#     318                     "An error occurred while calling {0}{1}{2}.\n".
# --> 319                     format(target_id, ".", name), value)
#     320             else:
#     321                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling z:org.apache.spark.api.python.PythonRDD.collectAndServe.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 0 in stage 68.0 failed 1 times, most recent failure: Lost task 0.0 in stage 68.0 (TID 111, localhost, executor driver): org.apache.spark.api.python.PythonException: Traceback (most recent call last):
#   File "C:\spark\python\lib\pyspark.zip\pyspark\worker.py", line 174, in main
#   File "C:\spark\python\lib\pyspark.zip\pyspark\worker.py", line 169, in process
#   File "C:\spark\python\pyspark\rdd.py", line 2408, in pipeline_func
#     return func(split, prev_func(split, iterator))
#   File "C:\spark\python\pyspark\rdd.py", line 2408, in pipeline_func
#     return func(split, prev_func(split, iterator))
#   File "C:\spark\python\pyspark\rdd.py", line 345, in func
#     return f(iterator)
#   File "C:\spark\python\pyspark\rdd.py", line 1827, in combineLocally
#     merger.mergeValues(iterator)
#   File "C:\spark\python\lib\pyspark.zip\pyspark\shuffle.py", line 236, in mergeValues
#     for k, v in iterator:
#   File "<ipython-input-116-c40cb38582e2>", line 2, in <lambda>
# IndexError: list index out of range
#
# 	at org.apache.spark.api.python.PythonRunner$$anon$1.read(PythonRDD.scala:193)
# 	at org.apache.spark.api.python.PythonRunner$$anon$1.<init>(PythonRDD.scala:234)
# 	at org.apache.spark.api.python.PythonRunner.compute(PythonRDD.scala:152)
# 	at org.apache.spark.api.python.PythonRDD.compute(PythonRDD.scala:63)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:323)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:287)
# 	at org.apache.spark.api.python.PairwiseRDD.compute(PythonRDD.scala:390)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:323)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:287)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:96)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:53)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:99)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:322)
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.lang.Thread.run(Unknown Source)
#
# Driver stacktrace:
# 	at org.apache.spark.scheduler.DAGScheduler.org$apache$spark$scheduler$DAGScheduler$$failJobAndIndependentStages(DAGScheduler.scala:1435)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$abortStage$1.apply(DAGScheduler.scala:1423)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$abortStage$1.apply(DAGScheduler.scala:1422)
# 	at scala.collection.mutable.ResizableArray$class.foreach(ResizableArray.scala:59)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:48)
# 	at org.apache.spark.scheduler.DAGScheduler.abortStage(DAGScheduler.scala:1422)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$handleTaskSetFailed$1.apply(DAGScheduler.scala:802)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$handleTaskSetFailed$1.apply(DAGScheduler.scala:802)
# 	at scala.Option.foreach(Option.scala:257)
# 	at org.apache.spark.scheduler.DAGScheduler.handleTaskSetFailed(DAGScheduler.scala:802)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.doOnReceive(DAGScheduler.scala:1650)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:1605)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:1594)
# 	at org.apache.spark.util.EventLoop$$anon$1.run(EventLoop.scala:48)
# 	at org.apache.spark.scheduler.DAGScheduler.runJob(DAGScheduler.scala:628)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:1925)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:1938)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:1951)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:1965)
# 	at org.apache.spark.rdd.RDD$$anonfun$collect$1.apply(RDD.scala:936)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:112)
# 	at org.apache.spark.rdd.RDD.withScope(RDD.scala:362)
# 	at org.apache.spark.rdd.RDD.collect(RDD.scala:935)
# 	at org.apache.spark.api.python.PythonRDD$.collectAndServe(PythonRDD.scala:453)
# 	at org.apache.spark.api.python.PythonRDD.collectAndServe(PythonRDD.scala)
# 	at sun.reflect.GeneratedMethodAccessor41.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(Unknown Source)
# 	at java.lang.reflect.Method.invoke(Unknown Source)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:280)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:214)
# 	at java.lang.Thread.run(Unknown Source)
# Caused by: org.apache.spark.api.python.PythonException: Traceback (most recent call last):
#   File "C:\spark\python\lib\pyspark.zip\pyspark\worker.py", line 174, in main
#   File "C:\spark\python\lib\pyspark.zip\pyspark\worker.py", line 169, in process
#   File "C:\spark\python\pyspark\rdd.py", line 2408, in pipeline_func
#     return func(split, prev_func(split, iterator))
#   File "C:\spark\python\pyspark\rdd.py", line 2408, in pipeline_func
#     return func(split, prev_func(split, iterator))
#   File "C:\spark\python\pyspark\rdd.py", line 345, in func
#     return f(iterator)
#   File "C:\spark\python\pyspark\rdd.py", line 1827, in combineLocally
#     merger.mergeValues(iterator)
#   File "C:\spark\python\lib\pyspark.zip\pyspark\shuffle.py", line 236, in mergeValues
#     for k, v in iterator:
#   File "<ipython-input-116-c40cb38582e2>", line 2, in <lambda>
# IndexError: list index out of range
#
# 	at org.apache.spark.api.python.PythonRunner$$anon$1.read(PythonRDD.scala:193)
# 	at org.apache.spark.api.python.PythonRunner$$anon$1.<init>(PythonRDD.scala:234)
# 	at org.apache.spark.api.python.PythonRunner.compute(PythonRDD.scala:152)
# 	at org.apache.spark.api.python.PythonRDD.compute(PythonRDD.scala:63)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:323)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:287)
# 	at org.apache.spark.api.python.PairwiseRDD.compute(PythonRDD.scala:390)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:323)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:287)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:96)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:53)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:99)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:322)
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	... 1 more

# %%
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-92-11ed8edc80e6> in <module>()
#       1 #get Year
#       2 years = textFile.map(lambda textFile: (textFile.split(';')[4]))
# ----> 3 print(years.collect())
#       4 #print(years.collect()[0:5])
#       5 #counts = years.reduceByKey(lambda a, b: a + b)
#
# C:\spark\python\pyspark\rdd.py in collect(self)
#     806         """
#     807         with SCCallSiteSync(self.context) as css:
# --> 808             port = self.ctx._jvm.PythonRDD.collectAndServe(self._jrdd.rdd())
#     809         return list(_load_from_socket(port, self._jrdd_deserializer))
#     810
#
# c:\python\lib\site-packages\py4j\java_gateway.py in __call__(self, *args)
#    1131         answer = self.gateway_client.send_command(command)
#    1132         return_value = get_return_value(
# -> 1133             answer, self.gateway_client, self.target_id, self.name)
#    1134
#    1135         for temp_arg in temp_args:
#
# c:\python\lib\site-packages\py4j\protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     317                 raise Py4JJavaError(
#     318                     "An error occurred while calling {0}{1}{2}.\n".
# --> 319                     format(target_id, ".", name), value)
#     320             else:
#     321                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling z:org.apache.spark.api.python.PythonRDD.collectAndServe.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 1 in stage 42.0 failed 1 times, most recent failure: Lost task 1.0 in stage 42.0 (TID 82, localhost, executor driver): org.apache.spark.api.python.PythonException: Traceback (most recent call last):
#   File "C:\spark\python\lib\pyspark.zip\pyspark\worker.py", line 174, in main
#   File "C:\spark\python\lib\pyspark.zip\pyspark\worker.py", line 169, in process
#   File "C:\spark\python\lib\pyspark.zip\pyspark\serializers.py", line 268, in dump_stream
#     vs = list(itertools.islice(iterator, batch))
#   File "<ipython-input-92-11ed8edc80e6>", line 2, in <lambda>
# IndexError: list index out of range
#
# 	at org.apache.spark.api.python.PythonRunner$$anon$1.read(PythonRDD.scala:193)
# 	at org.apache.spark.api.python.PythonRunner$$anon$1.next(PythonRDD.scala:156)
# 	at org.apache.spark.api.python.PythonRunner$$anon$1.next(PythonRDD.scala:152)
# 	at org.apache.spark.InterruptibleIterator.next(InterruptibleIterator.scala:43)
# 	at scala.collection.Iterator$class.foreach(Iterator.scala:893)
# 	at org.apache.spark.InterruptibleIterator.foreach(InterruptibleIterator.scala:28)
# 	at scala.collection.generic.Growable$class.$plus$plus$eq(Growable.scala:59)
# 	at scala.collection.mutable.ArrayBuffer.$plus$plus$eq(ArrayBuffer.scala:104)
# 	at scala.collection.mutable.ArrayBuffer.$plus$plus$eq(ArrayBuffer.scala:48)
# 	at scala.collection.TraversableOnce$class.to(TraversableOnce.scala:310)
# 	at org.apache.spark.InterruptibleIterator.to(InterruptibleIterator.scala:28)
# 	at scala.collection.TraversableOnce$class.toBuffer(TraversableOnce.scala:302)
# 	at org.apache.spark.InterruptibleIterator.toBuffer(InterruptibleIterator.scala:28)
# 	at scala.collection.TraversableOnce$class.toArray(TraversableOnce.scala:289)
# 	at org.apache.spark.InterruptibleIterator.toArray(InterruptibleIterator.scala:28)
# 	at org.apache.spark.rdd.RDD$$anonfun$collect$1$$anonfun$13.apply(RDD.scala:936)
# 	at org.apache.spark.rdd.RDD$$anonfun$collect$1$$anonfun$13.apply(RDD.scala:936)
# 	at org.apache.spark.SparkContext$$anonfun$runJob$5.apply(SparkContext.scala:1951)
# 	at org.apache.spark.SparkContext$$anonfun$runJob$5.apply(SparkContext.scala:1951)
# 	at org.apache.spark.scheduler.ResultTask.runTask(ResultTask.scala:87)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:99)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:322)
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.lang.Thread.run(Unknown Source)
#
# Driver stacktrace:
# 	at org.apache.spark.scheduler.DAGScheduler.org$apache$spark$scheduler$DAGScheduler$$failJobAndIndependentStages(DAGScheduler.scala:1435)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$abortStage$1.apply(DAGScheduler.scala:1423)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$abortStage$1.apply(DAGScheduler.scala:1422)
# 	at scala.collection.mutable.ResizableArray$class.foreach(ResizableArray.scala:59)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:48)
# 	at org.apache.spark.scheduler.DAGScheduler.abortStage(DAGScheduler.scala:1422)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$handleTaskSetFailed$1.apply(DAGScheduler.scala:802)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$handleTaskSetFailed$1.apply(DAGScheduler.scala:802)
# 	at scala.Option.foreach(Option.scala:257)
# 	at org.apache.spark.scheduler.DAGScheduler.handleTaskSetFailed(DAGScheduler.scala:802)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.doOnReceive(DAGScheduler.scala:1650)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:1605)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:1594)
# 	at org.apache.spark.util.EventLoop$$anon$1.run(EventLoop.scala:48)
# 	at org.apache.spark.scheduler.DAGScheduler.runJob(DAGScheduler.scala:628)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:1925)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:1938)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:1951)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:1965)
# 	at org.apache.spark.rdd.RDD$$anonfun$collect$1.apply(RDD.scala:936)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:112)
# 	at org.apache.spark.rdd.RDD.withScope(RDD.scala:362)
# 	at org.apache.spark.rdd.RDD.collect(RDD.scala:935)
# 	at org.apache.spark.api.python.PythonRDD$.collectAndServe(PythonRDD.scala:453)
# 	at org.apache.spark.api.python.PythonRDD.collectAndServe(PythonRDD.scala)
# 	at sun.reflect.GeneratedMethodAccessor41.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(Unknown Source)
# 	at java.lang.reflect.Method.invoke(Unknown Source)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:280)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:214)
# 	at java.lang.Thread.run(Unknown Source)
# Caused by: org.apache.spark.api.python.PythonException: Traceback (most recent call last):
#   File "C:\spark\python\lib\pyspark.zip\pyspark\worker.py", line 174, in main
#   File "C:\spark\python\lib\pyspark.zip\pyspark\worker.py", line 169, in process
#   File "C:\spark\python\lib\pyspark.zip\pyspark\serializers.py", line 268, in dump_stream
#     vs = list(itertools.islice(iterator, batch))
#   File "<ipython-input-92-11ed8edc80e6>", line 2, in <lambda>
# IndexError: list index out of range
#
# 	at org.apache.spark.api.python.PythonRunner$$anon$1.read(PythonRDD.scala:193)
# 	at org.apache.spark.api.python.PythonRunner$$anon$1.next(PythonRDD.scala:156)
# 	at org.apache.spark.api.python.PythonRunner$$anon$1.next(PythonRDD.scala:152)
# 	at org.apache.spark.InterruptibleIterator.next(InterruptibleIterator.scala:43)
# 	at scala.collection.Iterator$class.foreach(Iterator.scala:893)
# 	at org.apache.spark.InterruptibleIterator.foreach(InterruptibleIterator.scala:28)
# 	at scala.collection.generic.Growable$class.$plus$plus$eq(Growable.scala:59)
# 	at scala.collection.mutable.ArrayBuffer.$plus$plus$eq(ArrayBuffer.scala:104)
# 	at scala.collection.mutable.ArrayBuffer.$plus$plus$eq(ArrayBuffer.scala:48)
# 	at scala.collection.TraversableOnce$class.to(TraversableOnce.scala:310)
# 	at org.apache.spark.InterruptibleIterator.to(InterruptibleIterator.scala:28)
# 	at scala.collection.TraversableOnce$class.toBuffer(TraversableOnce.scala:302)
# 	at org.apache.spark.InterruptibleIterator.toBuffer(InterruptibleIterator.scala:28)
# 	at scala.collection.TraversableOnce$class.toArray(TraversableOnce.scala:289)
# 	at org.apache.spark.InterruptibleIterator.toArray(InterruptibleIterator.scala:28)
# 	at org.apache.spark.rdd.RDD$$anonfun$collect$1$$anonfun$13.apply(RDD.scala:936)
# 	at org.apache.spark.rdd.RDD$$anonfun$collect$1$$anonfun$13.apply(RDD.scala:936)
# 	at org.apache.spark.SparkContext$$anonfun$runJob$5.apply(SparkContext.scala:1951)
# 	at org.apache.spark.SparkContext$$anonfun$runJob$5.apply(SparkContext.scala:1951)
# 	at org.apache.spark.scheduler.ResultTask.runTask(ResultTask.scala:87)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:99)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:322)
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	... 1 more

# %%
#EXAMPLE
pairs = people.map(lambda x: (x[4], 1))
counts = pairs.reduceByKey(lambda a, b: a + b)
print(counts.collect())
